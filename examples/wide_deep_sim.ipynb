# %%
import numpy as np
import matplotlib.pyplot as plt
from deep_anacal import simulate
# %load_ext autoreload
# %autoreload 2

# %%
sims = simulate.sim_wide_deep(
    seed=123,
    ngrid=64,
    scale=0.2,
    g1=0.2,
    fwhm_w=0.9,
    fwhm_d=0.7,
    s2n=20,
    deep_noise_frac=1./np.sqrt(10),
)

fig, axs = plt.subplots(ncols=2)
axs[0].imshow(sims["wide"])
axs[0].set_title('Wide')
axs[1].set_title('Deep')
axs[1].imshow(sims["deep"])
for i in range(2):
    axs[i].axis(False)
